# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\SOME_THINGS\Projects\python-examples\Note_Book\Machine_Learning\add_with_linear_regression\add.csv")

# %%
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       22 non-null     float64
#  1   y       22 non-null     float64
#  2   sum     22 non-null     float64
# dtypes: float64(3)
# memory usage: 656.0 bytes

# %%
plt.scatter(data=data,x='x',y='sum')
plt.title("x and sum")
plt.ylabel("sum")
plt.xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %%
plt.scatter(data=data,x='y',y='sum')
plt.title("y and sum")
plt.ylabel("sum")
plt.xlabel("y")
# Out:
# Text(0.5, 0, 'y')

# %% [markdown]
# ### 1. Store Feature Matrix In X And Response (Target) In Vector y

# %%
X=data[['x','y']]
y=data['sum']

# %% [markdown]
# ### 2. Train/Test Split
# #### 1. Split data into two part : a training set and a testing set
# #### 2. Train the model on training set
# #### 3. Test the Model on testing set

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.33)

# %%
X_train
# Out:
#          x       y
# 14    67.8    87.9
# 0      1.0     1.0
# 11   300.0    34.0
# 8     23.0    45.0
# 21  1000.0  3456.0
# 7    100.0    22.0
# 13    23.6    89.3
# 15   200.0   700.0
# 16   203.6    67.9
# 19   400.5   356.0
# 20    45.7   123.7
# 9     56.0    78.0
# 12    12.5    56.7
# 18    34.6    56.9

# %%
X_test
# Out:
#         x     y
# 6    55.0  80.0
# 2     6.0   6.0
# 1     4.0   4.0
# 3    10.0  10.0
# 10   13.0  78.0
# 17  400.0  45.7
# 5    23.0  43.0
# 4    30.0  30.0

# %%
y_train
# Out:
# 14     155.7
# 0        2.0
# 11     334.0
# 8       68.0
# 21    4456.0
# 7      122.0
# 13     112.9
# 15     900.0
# 16     271.5
# 19     756.5
# 20     169.4
# 9      134.0
# 12      69.2
# 18      91.5
# Name: sum, dtype: float64

# %%
y_test
# Out:
# 6     135.0
# 2      12.0
# 1       8.0
# 3      20.0
# 10     91.0
# 17    445.7
# 5      66.0
# 4      60.0
# Name: sum, dtype: float64

# %% [markdown]
# ### 3. Import & Train The Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train )
# Out:
# LinearRegression()

# %% [markdown]
# ### 4. Check Model’s Prediction Performance

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ### 5. Comparing The Results

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([135. ,  12. ,   8. ,  20. ,  91. , 445.7,  66. ,  60. ])

# %%
y_test
# Out:
# 6     135.0
# 2      12.0
# 1       8.0
# 3      20.0
# 10     91.0
# 17    445.7
# 5      66.0
# 4      60.0
# Name: sum, dtype: float64

# %%
df=pd.DataFrame({"actual":y_test,"Predict":y_pred})
df
# Out:
#     actual  Predict
# 6    135.0    135.0
# 2     12.0     12.0
# 1      8.0      8.0
# 3     20.0     20.0
# 10    91.0     91.0
# 17   445.7    445.7
# 5     66.0     66.0
# 4     60.0     60.0

# %% [markdown]
# ### 6. Prediction

# %%
model.predict([[100,11212]])
# Out:
# C:\Users\MoHaMeD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11312.])

# %%
model.predict([[100,2]])
# Out:
# C:\Users\MoHaMeD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([102.])

# %% [markdown]
# ### 7. Save Model Usign Joblib

# %%
import joblib

# %%
joblib.dump(model,'model_joblib')
# Out:
# ['model_joblib']

# %%
model = joblib.load('model_joblib')

# %%
model.predict([[10,40]])
# Out:
# C:\Users\MoHaMeD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([50.])
